# %%
import numpy as np
T = 1.0
K_grid = 10
dt   = T / K_grid
taus = T - np.arange(0, K_grid + 1) * dt
taus
# Out:
# array([1.        , 0.98076923, 0.96153846, 0.94230769, 0.92307692,
#        0.90384615, 0.88461538, 0.86538462, 0.84615385, 0.82692308,
#        0.80769231, 0.78846154, 0.76923077, 0.75      , 0.73076923,
#        0.71153846, 0.69230769, 0.67307692, 0.65384615, 0.63461538,
#        0.61538462, 0.59615385, 0.57692308, 0.55769231, 0.53846154,
#        0.51923077, 0.5       , 0.48076923, 0.46153846, 0.44230769,
#        0.42307692, 0.40384615, 0.38461538, 0.36538462, 0.34615385,
#        0.32692308, 0.30769231, 0.28846154, 0.26923077, 0.25      ,
#        0.23076923, 0.21153846, 0.19230769, 0.17307692, 0.15384615,
#        0.13461538, 0.11538462, 0.09615385, 0.07692308, 0.05769231,
#        0.03846154, 0.01923077, 0.        ])
